# %%
import pandas as pd
import numpy as np
import re

# %%
ing_list_df = pd.read_csv('master_ingredient_dataframe.csv')

# %%
ing_list_df
# Out:
#                           ingredient  count  Unnamed: 2  \
# 0     bone in skin on chicken thighs     19         NaN
# 1                 bone in pork chops     25         NaN
# 2                        black beans     23         NaN
# 3                       acorn squash     13         NaN
# 4                    american cheese     14         NaN
# ...                              ...    ...         ...
# 1069                   yellow pepper     55         NaN
# 1070                          yogurt     97         NaN
# 1071               yukon gold potato     24         NaN
# 1072                          zaatar      9         NaN
# 1073                        zucchini    176         NaN
#
#                                              Unnamed: 3     Unnamed: 4
# 0     if re.search('(?:$|\s)[Cc]hicken(?!\sstock|\sb...        chicken
# 1     if re.search('(?:$|\s)[Pp]ork|[spare\sribs(?:\...           pork
# 2     if re.search('(?:$|\s)bean(?!\ssauce)',<string>):          beans
# 3     if re.search('(?:(?<=acorn)|(?<=butternut))\s*...  winter squash
# 4     if re.search('(?:(?<=american\s)|(?<=cottage\s...         cheese
# ...                                                 ...            ...
# 1069                                                NaN            NaN
# 1070                                                NaN            NaN
# 1071                                                NaN            NaN
# 1072                                                NaN            NaN
# 1073                                                NaN            NaN
#
# [1074 rows x 5 columns]

# %%
ingredient_list = ing_list_df.ingredient.tolist()

# %%
if re.search('(?:^|\s)[Cc]hicken(?!sstock|\sbroth|\sbouillon|\sbase)','chicken gfd'):
       print('chicken')
# Out:
# chicken

# %%
corrected_ingredient_list = []
for index, element in enumerate(ingredient_list):
    if re.search('(?:^|\s)[Cc]hicken(?!sstock|\sbroth|\sbouillon|\sbase)',element):
       corrected_ingredient_list.append('chicken')
    elif re.search('(?:$|\s)[Pp]ork|[Bb]aby\sback|[Bb]oston\sbutt(?:\s|$)',element):
       corrected_ingredient_list.append('pork')
    elif re.search('(?:$|\s)bean(?!\ssauce)',element):
       corrected_ingredient_list.append('beans') 
    elif re.search('(?:(?<=acorn)|(?<=butternut))\s*squash(?:$|\s)', element):
       corrected_ingredient_list.append('winter squash')
    elif re.search('(?:(?<=american\s)|(?<=cottage\s)|(?<=mexican\s)|(?<=cheddar\s)|(?<=shredded\s)|(?<=swiss\s)|(?<=cream\s)|(?<=^))cheese(?:$|\s)', element):
       corrected_ingredient_list.append('cheese')
    elif re.search('(?:(?<=asiago\s)|(?<=ricotta\s)|(?<=mozzarella\s)|(?<=parmessan\s)|(?<=^))cheese(?:$|\s)', element):
       corrected_ingredient_list.append('italian cheese')
    elif re.search('(?:(?<=black\s)|(?<=green\s)|(?<=pink\s))[Pp]epper(?:corns|\s|$)', element):
       corrected_ingredient_list.append('pepper')
    elif re.search('(?:(?<=blue\s)|(?<=feta\s)|(?<=goat\s)|(?<=^))cheese(?:$|\s)', element):
       corrected_ingredient_list.append('mediterranean cheese')
    elif re.search('(?:(?<=green)|(?<=yellow)|(?<=orange)|(?<=red)|(?<=bell))\spepper(?:$|\s)', element):
       corrected_ingredient_list.append('bell pepper')
    elif re.search('(?:^|\s)[Aa]maranth|[Bb]arley|[Qq]uinoa(?:$|\s)',element):
       corrected_ingredient_list.append('grain')
    elif re.search('(?:^|\s)[Aa]ncho(?:$|\s)', element):
       corrected_ingredient_list.append('ancho pepper')
    elif re.search('(?:^|\s)[Aa]nchovy(?:$|\s)', element):
       corrected_ingredient_list.append('anchovy')
    elif re.search('(?:^|\s)[Aa]pple(?:$)', element):
       corrected_ingredient_list.append('apple')
    elif re.search('(?:^|\s)[Aa]pple\s(?:cider|juice)(?!\svinegar)', element):
       corrected_ingredient_list.append('apple juice')
    elif re.search('(?:^|\s)[Aa]pricot(?:$|\s)', element):
       corrected_ingredient_list.append('apricot')
    elif re.search('(?:^|\s)[Bb]alsamic(?:\sglaze|$)', element):
       corrected_ingredient_list.append('balsamic')
    elif re.search('(?:^|\s)[Bb]acon(?:$|\s)', element):
       corrected_ingredient_list.append('bacon')
    elif re.search('(?:^|\s)[Bb]anana\spepper(?:$|\s|s)', element):
       corrected_ingredient_list.append('fresh pepper')
    elif re.search('(?:^|\s)[Bb]ase|[Ss]tock|[Bb]ouillon|[Bb]roth(?:$|\s)', element):
       corrected_ingredient_list.append('broth')
    elif re.search('(?:^|\s)[Bb]asil(?!\spesto)', element):
       corrected_ingredient_list.append('basil')
    elif re.search('(?:^|\s)[Bb]eef(?!\sbroth|\sbase|\sstock|\sbouillon|steak|\sgravy)', element):
       corrected_ingredient_list.append('beef')
    elif re.search('(?:^|\s)[Bb]eet(?:$|\s|s)', element):
       corrected_ingredient_list.append('beets')
    elif re.search('(?:(?:^)|(?:\s))[Cc]arrots(?:$|\s)', element):
       corrected_ingredient_list.append('carrots')
    elif re.search('(?:^|\s)[Cc]ardamom(?:$|\s|s)', element):
       corrected_ingredient_list.append('cardomom')
    elif re.search('(?:^|\s)[Cc]hocolate(?:$|\s)',element):
       corrected_ingredient_list.append('chocolate')
    elif re.search('(?:^|\s)[cC]orn(?:$|\s)', element):
       corrected_ingredient_list.append('corn')
    elif re.search('(?:^|\s)[Ee]ggplant(?:$|\s|s)', element):
       corrected_ingredient_list.append('eggplant')
    elif re.search('(?:^|\s)[Gg]ravy(?:$|\s)', element):
       corrected_ingredient_list.append('gravy')
    elif re.search('(?:^|\s)[Ll]entil(?:$|\s|s)', element):
       corrected_ingredient_list.append('lentils')
    elif re.search('(?:^|\s)[Mm]ilk(?:$|\s)',element):
       corrected_ingredient_list.append('milk')
    elif re.search('(?:^|\s)[Oo]live(?!\soil)', element):
       corrected_ingredient_list.append('olives')
    elif re.search('(?:^|\s)[Pp]asta(?:$|\s)', element):
       corrected_ingredient_list.append('pasta')
    elif re.search('(?:^|\s)[Pp]ear(?:$|\s|s)', element):
       corrected_ingredient_list.append('pear')
    elif re.search('(?:^|\s)[Pp]esto(?:$|\s)', element):
       corrected_ingredient_list.append('pesto')
    elif re.search('(?:^|\s)[Rr]ice(?!\sflour|\spudding|d)(?:$|\s)', element):
       corrected_ingredient_list.append('rice')
    elif re.search('(?:^|\s)[Ss]pinach(?:$|\s|s)', element):
       corrected_ingredient_list.append('spinach')
    elif re.search('(?:^|\s)[Tt]una(?:$|\s)',element):
       corrected_ingredient_list.append('fish')
    elif re.search('(?:^|\s)[Tt]omato\w*(?!\spaste|\ssauce)', element):
       corrected_ingredient_list.append('tomato')
    elif re.search('(?:^|\s)[Vv]inegar(?:$|\s)', element):
       corrected_ingredient_list.append('vinegar')
    elif re.search('(?:^|\s)[Vv]anilla(?!\sice|\scake)', element):
       corrected_ingredient_list.append('vanilla')
    elif re.search('(?:^|\s)masala(?:$|\s)', element):
       corrected_ingredient_list.append('masala')
    elif re.search('(?:^|\s|\w)berries|berry(?:$|\s)', element):
       corrected_ingredient_list.append('berries')
    elif re.search('(?:black|green|pink|\s)[Pp]epper(?:corns|\s|$)', element):
       corrected_ingredient_list.append('black pepper')
    elif re.search('(?:^|\s)[Aa]lmond(?!\smilk)', element):
       corrected_ingredient_list.append('almonds')
    elif re.search('(?:^|\s)[Oo]il(?:\s|$)', element):
       corrected_ingredient_list.append('oil')
    elif re.search('(?:^|\s)[Aa]vocado(?!\soil)', element):
       corrected_ingredient_list.append('avocado')
    elif re.search('(?:^|\s)[Tt]urkey(?!\sstock|\sbroth)', element):
       corrected_ingredient_list.append('turkey')
    elif re.search('(?:^|\s)[Bb]read(?!\sflour|crumbs)', element):
       corrected_ingredient_list.append('bread')
    elif re.search('(?:^|\s)[Bb]ratwurst|[Cc]horizo|[Ss]ausage(?:$|\s)', element):
       corrected_ingredient_list.append('sausage')
    elif re.search('(?:^|\s)[Bb]roccoli(?:$|\sfloret)', element):
       corrected_ingredient_list.append('broccoli')
    elif re.search('(?:^|\s)[Mm]ustard\sseed(?:$|s)', element):
       corrected_ingredient_list.append('mustard seed')
    elif re.search('(?:(?:^)|(?:clarified\s)|(?:unsalted\s))[Bb]utter(?!\slettuce)', element):
       corrected_ingredient_list.append('butter')
    elif re.search('(?:^|\s)[Cc]]abbage(?:$|/s)', element):
       corrected_ingredient_list.append('cabbage')
    elif re.search('(?:^|\s)[Cc]urry\spaste(?:$|/s)', element):
       corrected_ingredient_list.append('curry paste')
    elif re.search('(?:^|\s)[Pp]ineapple(?:$|/s)', element):
       corrected_ingredient_list.append('pineapple')
    elif re.search('(?:(?:himalayan\s)|(?:coarse\s)|(?:sea\s)|($))[Ss]alt(?:$|/s)', element):
       corrected_ingredient_list.append('salt')
    elif re.search('(?:(?:\s)|(?:$))[Mm]ozzarella(?:$|/s)', element):
       corrected_ingredient_list.append('italian cheese')
    elif re.search('(?:^|\s)[Bb]utterscotch(?:$|/s)', element):
       corrected_ingredient_list.append('butterscotch')
    elif re.search('(?:(?:^)|(?:bread\s)|(?:cake\s)|wheat\s)[Ff]lour(?:$|/s)', element):
       corrected_ingredient_list.append('wheat flour')
    elif re.search('(?:(?:^)|(?:candied\s)|(?:crystalized\s)|(?:powdered\s)|(?:ground\s))[Gg]inger(?:$|/s)', element):
       corrected_ingredient_list.append('ginger')
    elif re.search('(?:(?:^)|(?:\s))[Bb]lackeyed\speas(?:$|/s)', element):
       corrected_ingredient_list.append('blackeyed peas')
    elif re.search('(?:(?:^)|(?:\s))[Oo]nion(?!\ssoup)', element):
       corrected_ingredient_list.append('onion')
    elif re.search('(?:(?:green\s)|(?:chipotle\s))[Cc]hile(?:\s|s|$)', element):
       corrected_ingredient_list.append('fresh chile')
    elif re.search('(?:(?:^)|(?:\s))[Cc]auliflower(?:\sfloret|$)', element):
       corrected_ingredient_list.append('cauliflower')
    elif re.search('(?:(?:^)|(?:\s))[Cc]elery(?!\ssalt|\sseed)', element):
       corrected_ingredient_list.append('celery')
    elif re.search('(?:(?:^)|(?:\s))[Cc]herry(?:\s|$)', element):
       corrected_ingredient_list.append('cherry')
    elif re.search('(?:(?:chickpea\s)|(?:rice\s)|(?:almond\s)|(?:coconut\s))[Ff]lour(?:\s|$)', element):
       corrected_ingredient_list.append('alt flour')
    elif re.search('(?:(?:^)|(?:\s))[Cc]innamon(?:\sstick|$)', element):
       corrected_ingredient_list.append('cinnamon')
     elif re.search('(?:(?:^)|(?:\s))[Cc]innamon(?:\sstick|$)', element):
       corrected_ingredient_list.append('cinnamon')
    else:
        corrected_ingredient_list.append(element)
corrected_ingredient_list
# Out:
# ['chicken',
#  'pork',
#  'beans',
#  'winter squash',
#  'cheese',
#  'italian cheese',
#  'pepper',
#  'mediterranean cheese',
#  'bell pepper',
#  'grain',
#  'ancho pepper',
#  'anchovy',
#  'apple',
#  'apple juice',
#  'apricot',
#  'balsamic',
#  'bacon',
#  'fresh pepper',
#  'broth',
#  'basil',
#  'beef',
#  'beets',
#  'carrots',
#  'cardomom',
#  'chocolate',
#  'corn',
#  'eggplant',
#  'broth',
#  'lentils',
#  'milk',
#  'olives',
#  'pasta',
#  'pear',
#  'pesto',
#  'rice',
#  'spinach',
#  'fish',
#  'tomato',
#  'vinegar',
#  'vanilla',
#  'vinegar',
#  'masala',
#  'berries',
#  'pepper',
#  'almonds',
#  'milk',
#  'agave',
#  'ajwain',
#  'alcohol',
#  'allspice',
#  'almonds',
#  'almonds',
#  'almonds',
#  'amaretto liqueur',
#  'amchoor',
#  'ancho pepper',
#  'sausage',
#  'angel food cake',
#  'angel food cake mix',
#  'anise',
#  'any color food color',
#  'apple juice',
#  'applesauce',
#  'apricot',
#  'arrowroot',
#  'artichoke',
#  'arugula',
#  'asafoetida',
#  'asparagus',
#  'avocado',
#  'oil',
#  'pork',
#  'bacon',
#  'baharat',
#  'chocolate',
#  'baking mix',
#  'baking soda',
#  'banana liqueur',
#  'barbecue sauce',
#  'grain',
#  'bay leaves',
#  'bean sprouts',
#  'beef',
#  'beef',
#  'broth',
#  'beef',
#  'beef',
#  'gravy',
#  'broth',
#  'beer',
#  'bitters',
#  'black bean sauce',
#  'black tea bag',
#  'berries',
#  'blackeyed peas',
#  'almonds',
#  'berries',
#  'berries',
#  'bok choy',
#  'beef',
#  'beef',
#  'pork',
#  'pork',
#  'chicken',
#  'chicken',
#  'chicken',
#  'turkey',
#  'boquerones',
#  'pork',
#  'bottle gourd',
#  'broth',
#  'bourbon',
#  'braggs liquid aminos',
#  'bran',
#  'brandy',
#  'sausage',
#  'bread',
#  'bread',
#  'bread',
#  'wheat flour',
#  'breadcrumbs',
#  'sausage',
#  'brie',
#  'broccoli',
#  'broccoli',
#  'broccoli rabe',
#  'broccolini',
#  'mustard seed',
#  'rice',
#  'brown rice flour',
#  'pasta',
#  'rice',
#  'brownie mix',
#  'brussels sprouts',
#  'wheat flour',
#  'italian cheese',
#  'burrito size tortilla',
#  'butter',
#  'butter lettuce',
#  'butter',
#  'butter',
#  'winter squash',
#  'butter',
#  'butter',
#  'cabbage',
#  'caesar salad dressing',
#  'cajun seasoning',
#  'wheat flour',
#  'bacon',
#  'ginger',
#  'candied orange peel',
#  'candy cane',
#  'chocolate',
#  'corn',
#  'candy melts',
#  'canned anchovies',
#  'beans',
#  'blackeyed peas',
#  'beans',
#  'beans',
#  'canned chickpeas',
#  'fresh chile',
#  'tomato',
#  'fresh chile',
#  'beans',
#  'beans',
#  'canned pumpkin',
#  'beans',
#  'canned tomato sauce',
#  'tomato',
#  'canned water chestnuts',
#  'beans',
#  'beans',
#  'capers',
#  'caramel sauce',
#  'onion',
#  'caraway seeds',
#  'cardomom',
#  'cardomom',
#  'carob powder',
#  'carrot',
#  'cashews',
#  'cassava',
#  'catfish',
#  'cauliflower',
#  'cauliflower',
#  'caviar',
#  'celery',
#  'celery salt',
#  'celery seed',
#  'celery',
#  'chai spice',
#  'chana dal',
#  'cheese',
#  'cheese',
#  'cheese',
#  'cherries',
#  'cherry',
#  'cherry',
#  'cherry',
#  'tomato',
#  'chia seeds',
#  'broth',
#  'broth',
#  'chicken',
#  'chicken',
#  'broth',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chicken',
#  'chickpea flour',
#  'chickpeas',
#  'beans',
#  'chili garlic sauce',
#  'oil',
#  'black pepper',
#  'chili powder',
#  'chili sauce',
#  'chinese five spice',
#  'cheese',
#  'chives',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'sausage',
#  'cilantro',
#  'cinnamon',
#  'cinnamon stick',
#  'butter',
#  'clove',
#  'coarse salt',
#  'coarse sea salt',
#  'cocoa nibs',
#  'coconut',
#  'coconut butter',
#  'coconut extract',
#  'coconut flour',
#  'coconut meat',
#  'milk',
#  'milk',
#  'oil',
#  'coconut rum',
#  'cod fillets',
#  'coffee',
#  'coffee extract',
#  'coffee liqueur',
#  'colby jack',
#  'coleslaw dressing',
#  'chicken',
#  'condensed cream of mushroom soup',
#  'bacon',
#  'rice',
#  'cooked cheese tortellini',
#  'chicken',
#  'chicken',
#  'cooked crabmeat',
#  'cooked grits',
#  'lentils',
#  'pasta',
#  'grain',
#  'rice',
#  'cooked rolled oats',
#  'cookie crumbs',
#  'cookies',
#  'oil',
#  'pasta',
#  'corn',
#  'corn',
#  'corn',
#  'corn',
#  'corn',
#  'corn',
#  'corn',
#  'cornbread',
#  'beef',
#  'beef',
#  'cornmeal',
#  'cotija cheese',
#  'cheese',
#  'couscous',
#  'crabmeat',
#  'cracked wheat',
#  'crackers',
#  'berries',
#  'berries',
#  'crawfish',
#  'cream',
#  'cheese',
#  'cream of tartar',
#  'cream soda',
#  'corn',
#  'creamy peanut butter',
#  'creme fraiche',
#  'creole mustard',
#  'creole seasoning',
#  'crepes',
#  'crimini mushrooms',
#  'croissant',
#  'croutons',
#  'bread',
#  'cucumber',
#  'cumin',
#  'cumin seeds',
#  'cupcakes',
#  'curly leaf lettuce',
#  'curry leaves',
#  'curry powder',
#  'daikon radish',
#  'dandelion greens',
#  'dark brown sugar',
#  'chocolate',
#  'chocolate',
#  'chocolate',
#  'oil',
#  'dates',
#  'dehydrated garlic',
#  'demerara sugar',
#  'diced ham',
#  'tomato',
#  'diet pop',
#  'digestive biscuits',
#  'dill',
#  'dill pickles',
#  'vinegar',
#  'double cream',
#  'douchi',
#  'dried apples',
#  'dried apricots',
#  'dried arbol chile',
#  'berries',
#  'basil',
#  'dried cherries',
#  'dried chickpeas',
#  'dried cilantro',
#  'berries',
#  'dried currants',
#  'dried dill',
#  'dried fenugreek leaves',
#  'dried figs',
#  'beans',
#  'dried mint',
#  'beans',
#  'dried parsley',
#  'pineapple',
#  'dried porcini mushrooms',
#  'lentils',
#  'berries',
#  'dried thyme',
#  'dry israeli couscous',
#  'dry red wine',
#  'dry seasoning rub',
#  'dry sherry',
#  'dry white wine',
#  'dry yeast',
#  'duck fat',
#  'dulce de leche',
#  'dungeness crab',
#  'egg',
#  'egg noodles',
#  'egg replacer',
#  'egg roll wrappers',
#  'egg substitute',
#  'egg whites',
#  'egg yolk',
#  'eggnog',
#  'eggplant',
#  'elbow macaroni',
#  'ener g egg replacer',
#  'english cucumber',
#  'english muffin',
#  'enoki mushrooms',
#  'escargot',
#  'escarole',
#  'espresso',
#  'milk',
#  'milk',
#  'extra firm tofu',
#  'cheese',
#  'oil',
#  'farfalle',
#  'farro',
#  'broth',
#  'fat free greek yogurt',
#  'fat free half and half',
#  'fat free mayonnaise',
#  'milk',
#  'vanilla',
#  'fat free whipped topping',
#  'fat free yogurt',
#  'beans',
#  'fennel',
#  'fennel seeds',
#  'mediterranean cheese',
#  'fettuccine',
#  'fig jam',
#  'figs',
#  'file powder',
#  'filo pastry',
#  'finely crushed pretzels',
#  'fingerling potato',
#  'tomato',
#  'fish',
#  'fish sauce',
#  'broth',
#  'flank steak',
#  'flavoring syrup',
#  'flax egg',
#  'flaxseed',
#  'flour tortilla',
#  'fontina cheese',
#  'berries',
#  'bread',
#  'basil',
#  'corn',
#  'fresh lavender',
#  'fresh marjoram',
#  'fresh mushrooms',
#  'fresh rosemary',
#  'frozen artichoke hearts',
#  'corn',
#  'spinach',
#  'fudge ice cream topping',
#  'apple',
#  'masala',
#  'garlic',
#  'garlic paste',
#  'garlic powder',
#  'garlic salt',
#  'gelatin',
#  'gherkins',
#  'ginger',
#  'ginger garlic paste',
#  'ginger juice',
#  'ginger paste',
#  'ginger powder',
#  'gingersnap crumbs',
#  'gluten free all purpose flour',
#  'chocolate',
#  'chocolate',
#  'gluten free flour mix',
#  'bread',
#  'mediterranean cheese',
#  'gochujang',
#  'beets',
#  'golden brown sugar',
#  'golden raisins',
#  'golden syrup',
#  'gorgonzola',
#  'gouda',
#  'graham cracker crumbs',
#  'graham cracker pie crust',
#  'graham crackers',
#  'grana padano',
#  'grand marnier',
#  'apple',
#  'granulated garlic',
#  'oil',
#  'tomato',
#  'grapefruit',
#  'grapes',
#  'greek yogurt',
#  'apple',
#  'beans',
#  'cardomom',
#  'black pepper',
#  'green enchilada sauce',
#  'green grapes',
#  'pepper',
#  'green tea bag',
#  'grenadine',
#  'grilling cheese',
#  'grits',
#  'black pepper',
#  'chicken',
#  'black pepper',
#  'ground chuck',
#  'ground cinnamon',
#  'ground clove',
#  'ground coffee',
#  'ground coriander',
#  'ground elk',
#  'ground fennel',
#  'ground flaxseed',
#  'ground lamb',
#  'pork',
#  'pork',
#  'ground sage',
#  'ground savory',
#  'ground sirloin',
#  'turkey',
#  'ground veal',
#  'gruyere',
#  'guacamole',
#  'guava',
#  'half and half',
#  'halibut fillets',
#  'ham',
#  'ham slices',
#  'ham steak',
#  'hamburger bun',
#  'hard boiled egg',
#  'harissa',
#  'hash browns',
#  'havarti',
#  'hawaiian rock cod',
#  'hawaiian roll',
#  'hazelnuts',
#  'milk',
#  'herbes de provence',
#  'hersheys cocoa',
#  'milk',
#  'hibiscus',
#  'hoisin sauce',
#  'hollandaise sauce',
#  'hollandaise sauce mix',
#  'honey',
#  'honey dijon mustard',
#  'honey mustard',
#  'horseradish',
#  'hot cocoa mix',
#  'hot sauce',
#  'ice',
#  'icing',
#  'imitation crab',
#  'chocolate',
#  'instant coffee',
#  'instant espresso',
#  'instant lemon pudding mix',
#  'instant potatoes flakes',
#  'vanilla',
#  'instant yeast',
#  'irish cream',
#  'sausage',
#  'italian seasoning',
#  'tomato',
#  'black pepper',
#  'jicama',
#  'juice',
#  'kabocha squash',
#  'olives',
#  'kale',
#  'kefir',
#  'kelp',
#  'ketchup',
#  'beans',
#  'korean bbq marinade',
#  'kosher salt',
#  'ladyfingers',
#  'lamb',
#  'lamb loin chop',
#  'lamb stew meat',
#  'lasagne noodles',
#  'bacon',
#  'pork',
#  'lebanese cucumber',
#  'leek',
#  'leg of lamb',
#  'legumes',
#  'lemon',
#  'basil',
#  'lemon cake mix',
#  'lemon curd',
#  'lemon extract',
#  'lemon flavored gelatin',
#  'lemon grass',
#  'lemon juice',
#  'lemon lime pop',
#  'lemon peel',
#  'black pepper',
#  'lemon pie filling',
#  'lemon wedge',
#  'lemonade',
#  'lemonade concentrate',
#  'lettuce',
#  'light beer',
#  'milk',
#  'light mayonnaise',
#  'oil',
#  'light sour cream',
#  'light soy sauce',
#  'lime',
#  'lime curd',
#  'lime juice',
#  'lime peel',
#  'lime wedge',
#  'linguine',
#  'liquid smoke',
#  'littleneck clams',
#  'rice',
#  'vanilla',
#  'low fat yogurt',
#  'low sodium baking powder',
#  'broth',
#  'broth',
#  'lower sodium soy sauce',
#  'lump crabmeat',
#  'macadamia nuts',
#  'mackerel',
#  'mandarin orange sections',
#  'mango',
#  'maple extract',
#  'maple flavoring',
#  'maple syrup',
#  'maraschino cherries',
#  'margarine',
#  'marie biscuits',
#  'marinated artichokes',
#  'marjoram',
#  'marsala',
#  'marshmallow cream',
#  'marshmallows',
#  'marzipan',
#  'masa harina',
#  'mascarpone',
#  'matcha',
#  'matzo meal',
#  'onion',
#  'mayonnaise',
#  'meat',
#  'medjool dates',
#  'mesclun',
#  'mexican crema',
#  'meyer lemon juice',
#  'milk',
#  'chocolate',
#  'milk',
#  'chocolate',
#  'mini filo shells',
#  'mini marshmallows',
#  'mini peppers',
#  'mint',
#  'miso',
#  'mixed fruit',
#  'mixed mushrooms',
#  'mixed vegetables',
#  'molasses',
#  'monterey jack cheese',
#  'montreal steak seasoning',
#  'moscato',
#  'mozzarella',
#  'berries',
#  'mustard',
#  'mustard powder',
#  'napa cabbage',
#  'navel orange',
#  'beans',
#  'nondairy creamer',
#  'milk',
#  'nut butter',
#  'nutmeg',
#  'nutritional yeast flakes',
#  'nuts',
#  'oat bran',
#  'oat flour',
#  'olives',
#  'tomato',
#  'okra',
#  'old bay seasoning',
#  'oil',
#  'olives',
#  'olives',
#  'onion',
#  'onion',
#  'orange',
#  'orange bitters',
#  'orange extract',
#  'orange juice',
#  'orange marmalade',
#  'bell pepper',
#  'orange slices',
#  'orange zest',
#  'oregano',
#  'oreo cookies',
#  'orzo',
#  'oyster sauce',
#  'oil',
#  'palm sugar',
#  'pancake mix',
#  'pancetta',
#  'paneer',
#  'panko',
#  'pappardelle',
#  'paprika',
#  'parmesan',
#  'parsley',
#  'parsnip',
#  'pasta',
#  'pasta',
#  'pastry flour',
#  'peach',
#  'peanut butter',
#  'peanut butter cups',
#  'oil',
#  'peanuts',
#  'pear',
#  'pear',
#  'onion',
#  'carrots',
#  'pecans',
#  'pecorino romano',
#  'penne',
#  'onion',
#  'pepperjack cheese',
#  'peppermint candy',
#  'peppermint extract',
#  'pepperoni',
#  'persian cucumber',
#  'petite peas',
#  'picante sauce',
#  'pickle juice',
#  'pickled jalapenos',
#  'pico de gallo',
#  'pie dough rounds',
#  'pimenton de la vera',
#  'pine nuts',
#  'pineapple',
#  'pineapple juice',
#  'pineapple rings',
#  'pineapple tidbits',
#  'pineapple with juice',
#  'salt',
#  'apple',
#  'beans',
#  'pistachio nuts',
#  'pita',
#  'pizza dough',
#  'pizza dough mix',
#  'plain greek yogurt',
#  'plain yogurt',
#  'plantain',
#  'tomato',
#  'black pepper',
#  'polenta',
#  'popcorn',
#  'poppy seeds',
#  'pork',
#  'pork belly',
#  'pork chops',
#  'pork loin chops',
#  'pork ribs',
#  'pork roast',
#  'sausage',
#  'pork seasoning',
#  'pork shoulder',
#  'pork spare ribs',
#  'pork tenderloin',
#  'port',
#  'portobello mushroom caps',
#  'pot roast',
#  'potato',
#  'potato starch',
#  'poultry seasoning',
#  'pound cake',
#  'milk',
#  'powdered sugar',
#  'prepared pizza crust',
#  'prepared polenta',
#  'prosciutto',
#  'provolone',
#  'prunes',
#  'puff pastry dough',
#  'rice',
#  'pumpkin pie mix',
#  'pumpkin pie spice',
#  'pumpkin seeds',
#  'purple plum',
#  'quail',
#  'quark',
#  'queso fresco',
#  'grain',
#  'radicchio',
#  'radish',
#  'raisins',
#  'ranch dressing',
#  'berries',
#  'berries',
#  'beets',
#  'red cabbage',
#  'curry paste',
#  'red food color',
#  'onion',
#  'bell pepper',
#  'bell pepper',
#  'red potato',
#  'red wine',
#  'vinegar',
#  'cheese',
#  'reduced fat peanut butter',
#  'beans',
#  'refrigerated cheese tortellini',
#  'refrigerated crescent rolls',
#  'rhubarb',
#  'rice',
#  'rice flour',
#  'milk',
#  'rice',
#  'rice',
#  'italian cheese',
#  'rigatoni',
#  'ripe banana',
#  'rice',
#  'beef',
#  'roasted peanuts',
#  'roasted red peppers',
#  'roasted unsalted pumpkin seeds',
#  'chicken',
#  'rolled oats',
#  'romaine',
#  'root vegetable',
#  'rose water',
#  'rosemary',
#  'chicken',
#  'round steak',
#  'rye beer',
#  'oil',
#  'saffron',
#  'sage',
#  'salad dressing',
#  'oil',
#  'salami',
#  'salmon',
#  'salmon steak',
#  'salsa',
#  'salsa verde',
#  'salt',
#  'black pepper',
#  'salt cod',
#  'salted butter',
#  'salted roasted cashews',
#  'sardines',
#  'sausage',
#  'savoy cabbage',
#  'scallops',
#  'scoops tortilla chips',
#  'scotch bonnet chili',
#  'seafood seasoning',
#  'seasoned breadcrumbs',
#  'seasoned salt',
#  'seasoning',
#  'seasoning mix',
#  'seeds',
#  'self rising flour',
#  'chocolate',
#  'chocolate',
#  'black pepper',
#  'oil',
#  'sesame seed burger bun',
#  'sesame seeds',
#  'shallot',
#  'shaoxing wine',
#  'cheese',
#  'sheep cheese',
#  'sherry',
#  'vinegar',
#  'shiitake mushrooms',
#  'rice',
#  'pasta',
#  'shortcrust pastry',
#  'shortening',
#  'cheese',
#  'cheese',
#  'chicken',
#  'cheese',
#  'italian cheese',
#  'shrimp',
#  'silken tofu',
#  'simple syrup',
#  'skirt steak',
#  'slider buns',
#  'almonds',
#  'smoked paprika',
#  'smoked salmon',
#  'sausage',
#  'snow peas',
#  'soba noodles',
#  'sorghum flour',
#  'sour cream',
#  'bread',
#  'soy buttery spread',
#  'soy flour',
#  'soy lecithin granules',
#  'soy pudding',
#  'soy sauce',
#  'soymilk',
#  'spaghetti',
#  'spaghetti squash',
#  'sausage',
#  'spare ribs',
#  'sparkling water',
#  'spelt flour',
#  'spices',
#  'spicy brown mustard',
#  'spinach',
#  'sponge cake',
#  'spring mix',
#  'onion',
#  'spring roll wrappers',
#  'sprinkles',
#  'sprouts',
#  'squash blossoms',
#  'sriracha',
#  'star anise',
#  'starchy potato',
#  'steak',
#  'steak sauce',
#  'steel cut oats',
#  'stevia',
#  'tomato',
#  'stinging nettle',
#  'broth',
#  'stout',
#  'berries',
#  'berries',
#  'berries',
#  'string cheese',
#  'sub bun',
#  'sucralose',
#  'sugar',
#  'sugar pumpkin',
#  'sugar snap peas',
#  'summer squash',
#  'tomato',
#  'sunflower kernels',
#  'oil',
#  'rice',
#  'sweet chili sauce',
#  'corn',
#  'sweet paprika',
#  'sweet potato',
#  'sweet potato vermicelli',
#  'sweet rice flour',
#  'sweetened coconut flakes',
#  'milk',
#  'swiss chard',
#  'cheese',
#  'swordfish',
#  'table syrup',
#  'taco seasoning mix',
#  'tahini',
#  'tamari',
#  'tamarind pulp',
#  'tangerine',
#  'tapioca starch',
#  'tarragon',
#  'apple',
#  'tartar sauce',
#  'tea',
#  'teff flour',
#  'tenderloin steak',
#  'tequila',
#  'teriyaki sauce',
#  'texas toast',
#  'basil',
#  'thai chili',
#  'bacon',
#  'thin baguette',
#  'thyme',
#  'tiger shrimp',
#  'tilapia',
#  'tofu',
#  'tomatillos',
#  'tomato',
#  'basil',
#  'tomato',
#  'tomato paste',
#  'tomato',
#  'tomato',
#  'tomato',
#  'top sirloin steak',
#  'tortilla',
#  'pasta',
#  'fish',
#  'turbinado sugar',
#  'bacon',
#  'turkey',
#  'turkey',
#  'broth',
#  'turmeric',
#  'turnip',
#  'twix',
#  'unbleached all purpose flour',
#  'unbleached flour',
#  'butter',
#  'unsalted peanuts',
#  'unsalted pistachios',
#  'chocolate',
#  'unsweetened coconut',
#  'milk',
#  ...]

# %%
corr_ing_list_df = pd.DataFrame(corrected_ingredient_list)

# %%
corr_ing_list_df.rename(columns={0:'ingredient'}, inplace=True)
corr_ing_list_df['count']=1

# %%
corr_ing_list_df = corr_ing_list_df.groupby('ingredient').agg({'count':'count'}).sort_values(by='count', ascending=False)

# %%
corr_ing_list_df.to_csv('ing_after_fifth_pass_regex.csv')
