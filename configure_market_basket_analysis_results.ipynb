# %%
import pandas as pd
import numpy as np

# %%
basket_analysis_spices_df = pd.read_csv('Exported_datafiles/market_basket_spices_all.csv', index_col = 0)
basket_analysis_spices_df
# Out:
#                 0             1          2         3       4
# 0        allspice      cinnamon        NaN       NaN     NaN
# 1          ginger      allspice        NaN       NaN     NaN
# 2          nutmeg      allspice        NaN       NaN     NaN
# 3         cayenne    asafoetida        NaN       NaN     NaN
# 4    chili powder    asafoetida        NaN       NaN     NaN
# ..            ...           ...        ...       ...     ...
# 108       paprika  fresh pepper   cilantro     cumin     NaN
# 109        nutmeg        ginger      clove  cinnamon     NaN
# 110     coriander        ginger   turmeric     cumin     NaN
# 111  chili powder    asafoetida  coriander   cayenne   cumin
# 112  chili powder      turmeric  coriander     cumin  ginger
#
# [113 rows x 5 columns]

# %%
basket_analysis_spices_df = basket_analysis_spices_df.rename(columns = {'0': 'entry_ing',
                                                                       '1':  'first_linked_ing',
                                                                       '2':  'second_linked_ing',
                                                                       '3':  'third_linked_ing',
                                                                       '4':  'fourth_linked_ing'})

# %%
basket_analysis_spices_df
# Out:
#         entry_ing first_linked_ing second_linked_ing third_linked_ing  \
# 0        allspice         cinnamon               NaN              NaN
# 1          ginger         allspice               NaN              NaN
# 2          nutmeg         allspice               NaN              NaN
# 3         cayenne       asafoetida               NaN              NaN
# 4    chili powder       asafoetida               NaN              NaN
# ..            ...              ...               ...              ...
# 108       paprika     fresh pepper          cilantro            cumin
# 109        nutmeg           ginger             clove         cinnamon
# 110     coriander           ginger          turmeric            cumin
# 111  chili powder       asafoetida         coriander          cayenne
# 112  chili powder         turmeric         coriander            cumin
#
#     fourth_linked_ing
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 108               NaN
# 109               NaN
# 110               NaN
# 111             cumin
# 112            ginger
#
# [113 rows x 5 columns]

# %%
matrix_rows = basket_analysis_spices_df.entry_ing.unique()

# %%
matrix_rows
# Out:
# array(['allspice', 'ginger', 'nutmeg', 'cayenne', 'chili powder',
#        'coriander', 'cumin', 'horseradish', 'cardomom', 'cilantro',
#        'clove', 'fenugreek', 'paprika', 'turmeric', 'thyme',
#        'fresh pepper', 'mustard seed'], dtype=object)

# %%
first_link_rows = basket_analysis_spices_df.first_linked_ing.unique()
first_link_rows
# Out:
# array(['cinnamon', 'allspice', 'asafoetida', 'bay leaves', 'cardomom',
#        'coriander', 'cumin', 'fresh chile', 'clove', 'fenugreek',
#        'turmeric', 'curry', 'rosemary', 'ginger', 'cayenne', 'mint',
#        'fresh pepper', 'prepared mustard', 'cilantro', 'oregano',
#        'paprika', 'thyme'], dtype=object)

# %%
second_link_rows = basket_analysis_spices_df.second_linked_ing.unique()
second_link_rows
# Out:
# array([nan, 'cinnamon', 'allspice', 'asafoetida', 'basil', 'cardomom',
#        'cayenne', 'cumin', 'cilantro', 'turmeric', 'ginger',
#        'fresh pepper', 'paprika', 'curry', 'clove', 'prepared mustard',
#        'coriander'], dtype=object)

# %%
third_link_rows = basket_analysis_spices_df.third_linked_ing.unique()
fourth_link_rows = basket_analysis_spices_df.fourth_linked_ing.unique()
fourth_link_rows
# Out:
# array([nan, 'cumin', 'ginger'], dtype=object)

# %%
matrix_columns = []
for element in first_link_rows:
    if (element not in matrix_columns and element is not np.nan):
        matrix_columns.append(element)
for element in second_link_rows:
    if (element not in matrix_columns and element is not np.nan):
        matrix_columns.append(element)
for element in third_link_rows:
    if element not in matrix_columns and element is not np.nan:
        matrix_columns.append(element)        
for element in third_link_rows:
    if element not in matrix_columns and element is not np.nan:
        matrix_columns.append(element)        

matrix_columns
# Out:
# ['cinnamon',
#  'allspice',
#  'asafoetida',
#  'bay leaves',
#  'cardomom',
#  'coriander',
#  'cumin',
#  'fresh chile',
#  'clove',
#  'fenugreek',
#  'turmeric',
#  'curry',
#  'rosemary',
#  'ginger',
#  'cayenne',
#  'mint',
#  'fresh pepper',
#  'prepared mustard',
#  'cilantro',
#  'oregano',
#  'paprika',
#  'thyme',
#  'basil']

# %%
basket_analysis_spices_df.set_index('entry_ing')
# Out:
#              first_linked_ing second_linked_ing third_linked_ing  \
# entry_ing
# allspice             cinnamon               NaN              NaN
# ginger               allspice               NaN              NaN
# nutmeg               allspice               NaN              NaN
# cayenne            asafoetida               NaN              NaN
# chili powder       asafoetida               NaN              NaN
# ...                       ...               ...              ...
# paprika          fresh pepper          cilantro            cumin
# nutmeg                 ginger             clove         cinnamon
# coriander              ginger          turmeric            cumin
# chili powder       asafoetida         coriander          cayenne
# chili powder         turmeric         coriander            cumin
#
#              fourth_linked_ing
# entry_ing
# allspice                   NaN
# ginger                     NaN
# nutmeg                     NaN
# cayenne                    NaN
# chili powder               NaN
# ...                        ...
# paprika                    NaN
# nutmeg                     NaN
# coriander                  NaN
# chili powder             cumin
# chili powder            ginger
#
# [113 rows x 4 columns]

# %%
output_list = []

for row in range (0, len(matrix_rows)):
    result_row = []
    for col in range (0, len(matrix_columns)):
        result_row.append(0)
    output_list.append(result_row)
output_list
result_df = pd.DataFrame(output_list, columns = matrix_columns, index=matrix_rows)
result_df
# Out:
#               cinnamon  allspice  asafoetida  bay leaves  cardomom  coriander  \
# allspice             0         0           0           0         0          0
# ginger               0         0           0           0         0          0
# nutmeg               0         0           0           0         0          0
# cayenne              0         0           0           0         0          0
# chili powder         0         0           0           0         0          0
# coriander            0         0           0           0         0          0
# cumin                0         0           0           0         0          0
# horseradish          0         0           0           0         0          0
# cardomom             0         0           0           0         0          0
# cilantro             0         0           0           0         0          0
# clove                0         0           0           0         0          0
# fenugreek            0         0           0           0         0          0
# paprika              0         0           0           0         0          0
# turmeric             0         0           0           0         0          0
# thyme                0         0           0           0         0          0
# fresh pepper         0         0           0           0         0          0
# mustard seed         0         0           0           0         0          0
#
#               cumin  fresh chile  clove  fenugreek  ...  ginger  cayenne  \
# allspice          0            0      0          0  ...       0        0
# ginger            0            0      0          0  ...       0        0
# nutmeg            0            0      0          0  ...       0        0
# cayenne           0            0      0          0  ...       0        0
# chili powder      0            0      0          0  ...       0        0
# coriander         0            0      0          0  ...       0        0
# cumin             0            0      0          0  ...       0        0
# horseradish       0            0      0          0  ...       0        0
# cardomom          0            0      0          0  ...       0        0
# cilantro          0            0      0          0  ...       0        0
# clove             0            0      0          0  ...       0        0
# fenugreek         0            0      0          0  ...       0        0
# paprika           0            0      0          0  ...       0        0
# turmeric          0            0      0          0  ...       0        0
# thyme             0            0      0          0  ...       0        0
# fresh pepper      0            0      0          0  ...       0        0
# mustard seed      0            0      0          0  ...       0        0
#
#               mint  fresh pepper  prepared mustard  cilantro  oregano  \
# allspice         0             0                 0         0        0
# ginger           0             0                 0         0        0
# nutmeg           0             0                 0         0        0
# cayenne          0             0                 0         0        0
# chili powder     0             0                 0         0        0
# coriander        0             0                 0         0        0
# cumin            0             0                 0         0        0
# horseradish      0             0                 0         0        0
# cardomom         0             0                 0         0        0
# cilantro         0             0                 0         0        0
# clove            0             0                 0         0        0
# fenugreek        0             0                 0         0        0
# paprika          0             0                 0         0        0
# turmeric         0             0                 0         0        0
# thyme            0             0                 0         0        0
# fresh pepper     0             0                 0         0        0
# mustard seed     0             0                 0         0        0
#
#               paprika  thyme  basil
# allspice            0      0      0
# ginger              0      0      0
# nutmeg              0      0      0
# cayenne             0      0      0
# chili powder        0      0      0
# coriander           0      0      0
# cumin               0      0      0
# horseradish         0      0      0
# cardomom            0      0      0
# cilantro            0      0      0
# clove               0      0      0
# fenugreek           0      0      0
# paprika             0      0      0
# turmeric            0      0      0
# thyme               0      0      0
# fresh pepper        0      0      0
# mustard seed        0      0      0
#
# [17 rows x 23 columns]

# %%
basket_analysis_spices_df.columns
# Out:
# Index(['entry_ing', 'first_linked_ing', 'second_linked_ing',
#        'third_linked_ing', 'fourth_linked_ing'],
#       dtype='object')

# %%
basket_analysis_spices_df
# Out:
#         entry_ing first_linked_ing second_linked_ing third_linked_ing  \
# 0        allspice         cinnamon               NaN              NaN
# 1          ginger         allspice               NaN              NaN
# 2          nutmeg         allspice               NaN              NaN
# 3         cayenne       asafoetida               NaN              NaN
# 4    chili powder       asafoetida               NaN              NaN
# ..            ...              ...               ...              ...
# 108       paprika     fresh pepper          cilantro            cumin
# 109        nutmeg           ginger             clove         cinnamon
# 110     coriander           ginger          turmeric            cumin
# 111  chili powder       asafoetida         coriander          cayenne
# 112  chili powder         turmeric         coriander            cumin
#
#     fourth_linked_ing
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 108               NaN
# 109               NaN
# 110               NaN
# 111             cumin
# 112            ginger
#
# [113 rows x 5 columns]

# %%
type(basket_analysis_spices_df.loc[4,'second_linked_ing'])
# Out:
# float

# %%
for element in result_df.index.values:
    for row in basket_analysis_spices_df.index.values:
        if basket_analysis_spices_df.loc[row, 'entry_ing'] == element:
            for col in basket_analysis_spices_df.columns.values[1:4]:
                if basket_analysis_spices_df.loc[row, col] is not np.nan:
                    result_df.loc[element, basket_analysis_spices_df.loc[row, col]] = result_df.loc[element, basket_analysis_spices_df.loc[row, col]] + 1
result_df
# Out:
#               cinnamon  allspice  asafoetida  bay leaves  cardomom  coriander  \
# allspice             1         0           0           0         0          0
# ginger               6         2           0           0         2          0
# nutmeg               8         4           0           0         1          0
# cayenne              0         0           2           0         0          0
# chili powder         0         0           8           0         0         13
# coriander            0         0           4           0         0          0
# cumin                2         0           1           0         3          0
# horseradish          0         0           0           1         0          0
# cardomom             1         0           0           0         0          0
# cilantro             1         0           0           0         0          0
# clove                1         0           0           0         0          0
# fenugreek            0         0           0           0         0          0
# paprika              3         0           0           0         0          0
# turmeric             0         0           0           0         0          0
# thyme                0         0           0           0         0          0
# fresh pepper         0         0           0           0         0          0
# mustard seed         0         0           0           0         0          0
#
#               cumin  fresh chile  clove  fenugreek  ...  ginger  cayenne  \
# allspice          0            0      0          0  ...       0        0
# ginger            5            0      2          0  ...       0        2
# nutmeg            1            0      4          0  ...       5        0
# cayenne           1            0      0          0  ...       0        0
# chili powder     16            0      0          0  ...       5        8
# coriander        10            0      0          2  ...       3        3
# cumin             0            0      0          0  ...       2        1
# horseradish       0            0      0          0  ...       0        0
# cardomom          0            0      0          0  ...       0        0
# cilantro          1            1      0          0  ...       0        0
# clove             0            0      0          0  ...       0        0
# fenugreek         1            0      0          0  ...       0        0
# paprika           8            0      0          0  ...       0        2
# turmeric          2            0      0          0  ...       0        0
# thyme             1            0      0          0  ...       0        1
# fresh pepper      2            0      0          0  ...       0        1
# mustard seed      0            0      0          0  ...       0        0
#
#               mint  fresh pepper  prepared mustard  cilantro  oregano  \
# allspice         0             0                 0         0        0
# ginger           0             2                 0         5        0
# nutmeg           0             0                 0         0        0
# cayenne          0             0                 0         0        0
# chili powder     1             5                 0         1        4
# coriander        0             2                 0         1        0
# cumin            0             0                 0         1        0
# horseradish      0             0                 0         0        0
# cardomom         0             0                 0         0        0
# cilantro         0             0                 0         0        0
# clove            0             0                 0         0        0
# fenugreek        0             0                 0         0        0
# paprika          0             5                 0         5        1
# turmeric         0             0                 0         1        0
# thyme            0             1                 1         0        0
# fresh pepper     0             0                 0         1        0
# mustard seed     0             0                 1         0        0
#
#               paprika  thyme  basil
# allspice            0      0      0
# ginger              0      0      1
# nutmeg              0      0      0
# cayenne             0      0      0
# chili powder        5      0      1
# coriander           0      0      0
# cumin               0      0      0
# horseradish         0      0      0
# cardomom            0      0      0
# cilantro            0      0      0
# clove               0      0      0
# fenugreek           0      0      0
# paprika             0      0      0
# turmeric            0      0      0
# thyme               0      0      1
# fresh pepper        0      0      1
# mustard seed        0      1      0
#
# [17 rows x 23 columns]

# %%
result_df.to_csv('Exported_datafiles/market_basket_analysis_output_grid.csv')
